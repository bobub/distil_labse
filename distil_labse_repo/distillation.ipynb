# %% [markdown]
# ## Setup

# %% [markdown]
# ### Installs
# Setup environment once by running these cells when AWS instance is turned on

# %%
# !pip install transformers
# # #!pip install --upgrade torch --- do I really need this? 
# # # # makes deep learning container have diff environment --- or switch to pytorch_p37 latest?
# !pip install papermill
# # # !pip install lab-ml
# !pip install allennlp
# !pip install tensorboard

# %%
# %cd /home/ec2-user/SageMaker
# !git clone https://github.com/bobub/TextBrewer.git
# %cd TextBrewer
# !python setup.py install
# import os, sys
# sys.path.insert(0, "/home/ec2-user/SageMaker/TextBrewer/build/lib")

# %%
# %cd /home/ec2-user/SageMaker
# !git clone https://github.com/bobub/nn.git
# %cd /home/ec2-user/SageMaker/nn
# !python setup.py install
# import sys, os
# sys.path.insert(0, "/home/ec2-user/SageMaker/nn/build/lib")

# %% [markdown]
# ### Imports

# %%
import textbrewer
from textbrewer import GeneralDistiller
from textbrewer import TrainingConfig, DistillationConfig
from transformers import AutoConfig, AutoTokenizer, AutoModel, AdamW, AutoModelForMaskedLM
from transformers import get_linear_schedule_with_warmup, get_constant_schedule_with_warmup, get_cosine_schedule_with_warmup
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
from tqdm import tqdm
import seaborn as sns
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import pickle
from sagemaker import get_execution_role
import boto3
import time
import io
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import mean_squared_error
from functools import partial
from labml_nn.transformers.switch import SwitchTransformer, SwitchTransformerLayer, SwitchFeedForward
from labml_nn.transformers import MultiHeadAttention
from labml_nn.transformers.feed_forward import FeedForward
import torch.nn as nn
import datetime
import math
import json
from utils import *
from distil_funcs import *
#import papermill
from sklearn.decomposition import PCA
from transformers import BertModel, BertConfig

# %% [markdown]
# ### Papermill Arguments
# Papermill is used for hyperparameter tuning - see hyperparam_search.ipynb

# %%
# shows the tunable parameters during hyperparam search
# papermill.inspect_notebook('distillation.ipynb')

# %% [markdown]
# ### General Arguments

# %%
# GENERAL SETTINGS - for setting individual runs
TRAIN_DATA = 10000000
EVAL_DATA = 5000
BATCH_SIZE = 128
SHUFFLE = True
NUM_WORKERS = 4

# model
STUDENT = 'switch'
#'bert-base-multilingual-cased'
#'nreimers/TinyBERT_L-6_H-768_v2' , 
#"nreimers/TinyBERT_L-4_H-312_v2", 
# "distilbert-base-multilingual-cased"

# training config
NUM_STEPS = 80000 # steps of optimisation
NUM_EPOCHS = 5 # recommended 30-50
CKPT_FREQ = 1 # save X times per epoch
CKPT_EPOCH_FREQ = 1 # save every X epochs
CKPT_STEPS = 1 # save every X steps

#LOG_DIR = 's3://eu1-sagemaker-bucket/borisbubla/log/run-' + STUDENT + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") # '/home/ec2-user/SageMaker/log'
OUTPUT_DIR = 'models/'+STUDENT+'/time-'+datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
FP16 = False # use Apex mixed precision training
FP16_OPT_LEVEL = 'O1'
DATA_PARALLEL = False # use DataParallel training
LOCAL_RANK = -1 # Distributed DataParallel, check documentation
LEARNING_RATE = 1e-4
SCHEDULER_CLASS = get_linear_schedule_with_warmup
OPTIMIZER = AdamW
EVAL_METRIC = 'cosine_similarity'
DEVICE = 'cuda'

# distillation config
TEMPERATURE = 9
TEMPERATURE_SCHEDULER = 'constant'
KD_LOSS_TYPE = 'cos'
KD_LOSS_WEIGHT = 10 # (kd_weight,int_match_weight)
INT_LOSS_WEIGHT = 1
KD_WEIGHT_SCHEDULER = 'none'
IS_CACHING_LOGITS = False

# switch transformer settings
D_MODEL = 768
HEADS = 12
DROPOUT = 0.1
DROPOUT_FFN = 0.4
D_FF = 12
N_LAYERS = 2
N_EXPERTS = 320

# intermediate matches - TextBrewer framework
int_matches = (11,N_LAYERS-1)

# %%
 # need to be executed post Papermill injection parameters cell

GRADIENT_ACCUMULATION_STEPS = 1 #TRAIN_DATA/100000 #reduces GPU memory usage by only calling optimizer.step() every X backward 
#steps.
INTERMEDIATE_MATCHES = [    
        {'layer_T':int_matches[0], 'layer_S':int_matches[1], 'feature':'attention', 'loss': 'attention_ce', 'weight' : INT_LOSS_WEIGHT},#]
        {'layer_T':int_matches[0], 'layer_S':int_matches[1], 'feature':'value_relation', 'loss': 'value_relation_ce', 'weight' : INT_LOSS_WEIGHT}
    ]

LOG_DIR = 's3://eu1-sagemaker-bucket/borisbubla/experiments/'+str(TRAIN_DATA/1000)+'k/'+STUDENT+'/LR'+str(LEARNING_RATE)+'LAY'+str(N_LAYERS)+'EXP'+str(N_EXPERTS)+'D_FF'+str(D_FF)+'TEMP'+str(TEMPERATURE)+'TIME-'+datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# %%
# Switch Transformer Configuration
student_config = {
    'd_model': D_MODEL, # hidden dim of model
    'heads': HEADS, # attention heads
    'dropout':DROPOUT, # dropout in network except ffn
    'dropout_ffn':DROPOUT_FFN, # dropout in ffn 
    'd_ff': D_FF, # num features in FFN hidden layer
    'n_layers': N_LAYERS, # num of transformer layers
    'n_experts': N_EXPERTS, # number of FFN experts
    'load_balancing_loss_ceof': 0.01, # load balancing co-eff, encourages expert diversity
    'is_scale_prob': True, # whether to scale the selected expert outputs by routing probability
    'drop_tokens': False, # whether to drop tokens
    'capacity_factor':1.25, # capacity factor - seemed to work best in Switch Transformer
}

# %% [markdown]
# ### Setup DataLoader

# %%
# load OpenSubtitles data files
train_file = '/home/ec2-user/SageMaker/data/train.pkl'
valid_file = '/home/ec2-user/SageMaker/data/dev.pkl'
encoded_train_set = load_pickle(train_file)
encoded_valid_set = load_pickle(valid_file)

# %%
# Create Datasets
open_sub_train = CustomDataset(encoded_train_set['input_ids'][:TRAIN_DATA], 
                                      encoded_train_set['token_type_ids'][:TRAIN_DATA],
                                      encoded_train_set['attention_mask'][:TRAIN_DATA])
eval_dataset = CustomDataset(encoded_valid_set['input_ids'][:EVAL_DATA], 
                                      encoded_valid_set['token_type_ids'][:EVAL_DATA],
                                      encoded_valid_set['attention_mask'][:EVAL_DATA])

# Parameters
data_params = {'batch_size': BATCH_SIZE,
          'shuffle': SHUFFLE,
          'num_workers': NUM_WORKERS}

# Create DataLoader
dataloader = DataLoader(open_sub_train, **data_params)
# validation_generator = DataLoader(open_sub_valid, **params)

# %%
# save space
del encoded_train_set
del encoded_valid_set

# %% [markdown]
# ### Load Models

# %%
# set device - cuda or cpu
device = torch.device(DEVICE)
# load teacher
teacher_model = load_teacher(device=device)
# Out:
# Some weights of the model checkpoint at sentence-transformers/LaBSE were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# loads student - performs word embedding compression and weight initialsations too
student_model = load_student(name=STUDENT, student_config=student_config, device=device, teacher_model=teacher_model, int_matches=int_matches, N_LAYERS=N_LAYERS)

# %% [markdown]
# ## Distillation

# %% [markdown]
# ### Distillation Adaptor and Callback
#
# Manually run resume training cell or starting training cell

# %%
# IF RESUMING TRAINING
optimizer = OPTIMIZER(student_model.parameters(), lr=LEARNING_RATE)

# path of model state dict to resume training from
path = '/home/ec2-user/SageMaker/models/switch/time-20210620-201324/model_3136.pkl' 
checkpoint = torch.load(path, map_location = torch.device('cpu'))

# load optimiser and model
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
student_model.load_state_dict(checkpoint['model_state_dict'])

epoch = checkpoint['step']
losses_dict = checkpoint['losses_dict']
total_loss = checkpoint['total_loss']

student_model.train()
num_training_steps = NUM_STEPS

# arguments dict except optimiser 
scheduler_args = {'num_warmup_steps':int(0.1*num_training_steps), 'num_training_steps':num_training_steps}
del checkpoint

# %%
# IF STARTING TRAINING
# Epochs and training steps
num_training_steps = NUM_STEPS

# Optimizer and learning rate scheduler
optimizer = OPTIMIZER(student_model.parameters(), lr=LEARNING_RATE)

# arguments dict except 'optimizer'
scheduler_args = {'num_warmup_steps':int(0.1*num_training_steps), 'num_training_steps':num_training_steps}

# %%
callback_fun = partial(predict, teacher_model=teacher_model, eval_dataset=eval_dataset, device=device, STUDENT=STUDENT, BATCH_SIZE=BATCH_SIZE, eval_metric=EVAL_METRIC, feedback=True) # fill other arguments

# %% [markdown]
# ### Distillation Configurations and Model Overview

# %%
# display model parameters statistics
print("\nteacher_model's parameters:")
result, _ = textbrewer.utils.display_parameters(teacher_model,max_level=4)
print (result)

print("student_model's parameters:")
result, _ = textbrewer.utils.display_parameters(student_model,max_level=4)
print (result)
# Out:
# teacher_model's parameters:
#
# LAYER NAME                  	        #PARAMS	     RATIO	 MEM(MB)
# --model:                    	    470,927,360	   100.00%	 1796.45
#   --embeddings:             	    385,282,304	    81.81%	 1469.74
#     --position_ids:         	            512	     0.00%	    0.00
#     --word_embeddings
#       --weight:             	    384,885,504	    81.73%	 1468.22
#     --position_embeddings
#       --weight:             	        393,216	     0.08%	    1.50
#     --token_type_embeddings
#       --weight:             	          1,536	     0.00%	    0.01
#     --LayerNorm:            	          1,536	     0.00%	    0.01
#       --weight:             	            768	     0.00%	    0.00
#       --bias:               	            768	     0.00%	    0.00
#   --encoder
#     --layer:                	     85,054,464	    18.06%	  324.46
#       --0:                  	      7,087,872	     1.51%	   27.04
#         --attention:        	      2,363,904	     0.50%	    9.02
#         --intermediate:     	      2,362,368	     0.50%	    9.01
#         --output:           	      2,361,600	     0.50%	    9.01
#       --1:                  	      7,087,872	     1.51%	   27.04
#         --attention:        	      2,363,904	     0.50%	    9.02
#         --intermediate:     	      2,362,368	     0.50%	    9.01
#         --output:           	      2,361,600	     0.50%	    9.01
#       --2:                  	      7,087,872	     1.51%	   27.04
#         --attention:        	      2,363,904	     0.50%	    9.02
#         --intermediate:     	      2,362,368	     0.50%	    9.01
#         --output:           	      2,361,600	     0.50%	    9.01
#       --3:                  	      7,087,872	     1.51%	   27.04
#         --attention:        	      2,363,904	     0.50%	    9.02
#         --intermediate:     	      2,362,368	     0.50%	    9.01
#         --output:           	      2,361,600	     0.50%	    9.01
#       --4:                  	      7,087,872	     1.51%	   27.04
#         --attention:        	      2,363,904	     0.50%	    9.02
#         --intermediate:     	      2,362,368	     0.50%	    9.01
#         --output:           	      2,361,600	     0.50%	    9.01
#       --5:                  	      7,087,872	     1.51%	   27.04
#         --attention:        	      2,363,904	     0.50%	    9.02
#         --intermediate:     	      2,362,368	     0.50%	    9.01
#         --output:           	      2,361,600	     0.50%	    9.01
#       --6:                  	      7,087,872	     1.51%	   27.04
#         --attention:        	      2,363,904	     0.50%	    9.02
#         --intermediate:     	      2,362,368	     0.50%	    9.01
#         --output:           	      2,361,600	     0.50%	    9.01
#       --7:                  	      7,087,872	     1.51%	   27.04
#         --attention:        	      2,363,904	     0.50%	    9.02
#         --intermediate:     	      2,362,368	     0.50%	    9.01
#         --output:           	      2,361,600	     0.50%	    9.01
#       --8:                  	      7,087,872	     1.51%	   27.04
#         --attention:        	      2,363,904	     0.50%	    9.02
#         --intermediate:     	      2,362,368	     0.50%	    9.01
#         --output:           	      2,361,600	     0.50%	    9.01
#       --9:                  	      7,087,872	     1.51%	   27.04
#         --attention:        	      2,363,904	     0.50%	    9.02
#         --intermediate:     	      2,362,368	     0.50%	    9.01
#         --output:           	      2,361,600	     0.50%	    9.01
#       --10:                 	      7,087,872	     1.51%	   27.04
#         --attention:        	      2,363,904	     0.50%	    9.02
#         --intermediate:     	      2,362,368	     0.50%	    9.01
#         --output:           	      2,361,600	     0.50%	    9.01
#       --11:                 	      7,087,872	     1.51%	   27.04
#         --attention:        	      2,363,904	     0.50%	    9.02
#         --intermediate:     	      2,362,368	     0.50%	    9.01
#         --output:           	      2,361,600	     0.50%	    9.01
#   --pooler
#     --dense:                	        590,592	     0.13%	    2.25
#       --weight:             	        589,824	     0.13%	    2.25
#       --bias:               	            768	     0.00%	    0.00
#
# student_model's parameters:
#
# LAYER NAME               	        #PARAMS	     RATIO	 MEM(MB)
# --model:                 	    403,586,944	   100.00%	 1539.56
#   --switch_model:        	     18,701,440	     4.63%	   71.34
#     --layers:            	     17,518,720	     4.34%	   66.83
#       --0:               	      8,759,360	     2.17%	   33.41
#         --attn:          	      2,362,368	     0.59%	    9.01
#         --feed_forward:  	      6,393,920	     1.58%	   24.39
#         --norm_self_attn:	          1,536	     0.00%	    0.01
#         --norm_ff:       	          1,536	     0.00%	    0.01
#       --1:               	      8,759,360	     2.17%	   33.41
#         --attn:          	      2,362,368	     0.59%	    9.01
#         --feed_forward:  	      6,393,920	     1.58%	   24.39
#         --norm_self_attn:	          1,536	     0.00%	    0.01
#         --norm_ff:       	          1,536	     0.00%	    0.01
#     --norm:              	          1,536	     0.00%	    0.01
#       --weight:          	            768	     0.00%	    0.00
#       --bias:            	            768	     0.00%	    0.00
#     --linear:            	        590,592	     0.15%	    2.25
#       --weight:          	        589,824	     0.15%	    2.25
#       --bias:            	            768	     0.00%	    0.00
#     --pooler
#       --dense:           	        590,592	     0.15%	    2.25
#         --weight:        	        589,824	     0.15%	    2.25
#         --bias:          	            768	     0.00%	    0.00
#   --word_embeddings
#     --weight:            	    384,885,504	    95.37%	 1468.22

# %%
# Initialize configurations and distiller
train_config = TrainingConfig(
    gradient_accumulation_steps = GRADIENT_ACCUMULATION_STEPS,
    ckpt_frequency = CKPT_FREQ,
    ckpt_epoch_frequency = CKPT_EPOCH_FREQ,
    ckpt_steps = NUM_STEPS,
    output_dir = OUTPUT_DIR,
    fp16 = FP16,
    fp16_opt_level = FP16_OPT_LEVEL,
    data_parallel = DATA_PARALLEL,
    local_rank = LOCAL_RANK,
    device=device,
    log_dir=LOG_DIR

)
distill_config = DistillationConfig(
    temperature=TEMPERATURE,
    temperature_scheduler = TEMPERATURE_SCHEDULER,
    hard_label_weight=0,
    kd_loss_type=KD_LOSS_TYPE,
    kd_loss_weight = KD_LOSS_WEIGHT,
    kd_loss_weight_scheduler = KD_WEIGHT_SCHEDULER,
    is_caching_logits=IS_CACHING_LOGITS,
    intermediate_matches=INTERMEDIATE_MATCHES
)

# %%
print("TRAIN_CONFIG:")
print(train_config)

print("DISTILL_CONFIG:")
print(distill_config)
# Out:
# TRAIN_CONFIG:
# gradient_accumulation_steps : 1
# ckpt_frequency : 1
# ckpt_epoch_frequency : 1
# ckpt_steps : 28224
# log_dir : s3://eu1-sagemaker-bucket/borisbubla/experiments/10000.0k/switch/LR0.0001LAY2EXP320D_FF12TEMP9TIME-20210621-142400
# output_dir : models/switch/time-20210621-142359
# device : cuda
# fp16 : False
# fp16_opt_level : O1
# data_parallel : False
# local_rank : -1
#
# DISTILL_CONFIG:
# temperature : 9
# temperature_scheduler : <function constant_temperature_scheduler at 0x7facb2ae5ea0>
# hard_label_weight : 0
# hard_label_weight_scheduler : None
# kd_loss_type : cos
# kd_loss_weight : 10
# kd_loss_weight_scheduler : None
# probability_shift : False
# intermediate_matches : [
# IntermediateMatch: layer_T : 11, layer_S : 1, feature : attention, weight : 1, loss : attention_ce, proj : None,
# IntermediateMatch: layer_T : 11, layer_S : 1, feature : value_relation, weight : 1, loss : value_relation_ce, proj : None]
# is_caching_logits : False

# %% [markdown]
# ### Distillation Training

# %%
if STUDENT=='switch':
    distiller = GeneralDistiller(
    train_config=train_config, distill_config = distill_config,
    model_T = teacher_model, model_S = student_model, 
    adaptor_T = teacher_adaptor, adaptor_S = switch_student_adaptor,
    n_experts = student_config['n_experts'],
    load_balancing_loss_ceof = student_config['load_balancing_loss_ceof'])
    
if STUDENT!='switch':
    distiller = GeneralDistiller(
    train_config=train_config, distill_config = distill_config,
    model_T = teacher_model, model_S = student_model, 
    adaptor_T = simple_adaptor, adaptor_S = simple_adaptor,
    n_experts = 'none',
    load_balancing_loss_ceof = student_config['load_balancing_loss_ceof'])

start = time.time()
print('Start Time: ',start)
# Start distilling
with distiller:
    distiller.train(optimizer,dataloader, num_steps=NUM_STEPS, 
    scheduler_class=SCHEDULER_CLASS, scheduler_args = scheduler_args, callback=callback_fun)
end = time.time()

training_time = end-start
print('DONE! Time taken: ',training_time)
# Out:
# Start Time:  1624285505.461808
# Global Step:  1  of  28224
# Global Step:  2  of  28224
# Global Step:  3  of  28224
# Global Step:  4  of  28224
# Global Step:  5  of  28224
# Global Step:  6  of  28224
# Global Step:  7  of  28224
# Global Step:  8  of  28224
# Global Step:  9  of  28224
# Global Step:  10  of  28224
# Global Step:  11  of  28224
# Global Step:  12  of  28224
# Global Step:  13  of  28224
# Global Step:  14  of  28224
# Global Step:  15  of  28224
# Global Step:  16  of  28224
# Global Step:  17  of  28224
# Global Step:  18  of  28224
# Global Step:  19  of  28224
# Global Step:  20  of  28224
# Global Step:  21  of  28224
# Global Step:  22  of  28224
# Global Step:  23  of  28224
# Global Step:  24  of  28224
# Global Step:  25  of  28224
# Global Step:  26  of  28224
# Global Step:  27  of  28224
# Global Step:  28  of  28224
# Global Step:  29  of  28224
# Global Step:  30  of  28224
# Global Step:  31  of  28224
# Global Step:  32  of  28224
# Global Step:  33  of  28224
# Global Step:  34  of  28224
# Global Step:  35  of  28224
# Global Step:  36  of  28224
# Global Step:  37  of  28224
# Global Step:  38  of  28224
# Global Step:  39  of  28224
# Global Step:  40  of  28224
# Global Step:  41  of  28224
# Global Step:  42  of  28224
# Global Step:  43  of  28224
# Global Step:  44  of  28224
# Global Step:  45  of  28224
# Global Step:  46  of  28224
# Global Step:  47  of  28224
# Global Step:  48  of  28224
# Global Step:  49  of  28224
# Global Step:  50  of  28224
# Global Step:  51  of  28224
# Global Step:  52  of  28224
# Global Step:  53  of  28224
# Global Step:  54  of  28224
# Global Step:  55  of  28224
# Global Step:  56  of  28224
# Global Step:  57  of  28224
# Global Step:  58  of  28224
# Global Step:  59  of  28224
# Global Step:  60  of  28224
# Global Step:  61  of  28224
# Global Step:  62  of  28224
# Global Step:  63  of  28224
# Global Step:  64  of  28224
# Global Step:  65  of  28224
# Global Step:  66  of  28224
# Global Step:  67  of  28224
# Global Step:  68  of  28224
# Global Step:  69  of  28224
# Global Step:  70  of  28224
# Global Step:  71  of  28224
# Global Step:  72  of  28224
# Global Step:  73  of  28224
# Global Step:  74  of  28224
# Global Step:  75  of  28224
# Global Step:  76  of  28224
# Global Step:  77  of  28224
# Global Step:  78  of  28224
# Global Step:  79  of  28224
# Global Step:  80  of  28224
# Global Step:  81  of  28224
# Global Step:  82  of  28224
# Global Step:  83  of  28224
# Global Step:  84  of  28224
# Global Step:  85  of  28224
# Global Step:  86  of  28224
# Global Step:  87  of  28224
# Global Step:  88  of  28224
# Global Step:  89  of  28224
# Global Step:  90  of  28224
# Global Step:  91  of  28224
# Global Step:  92  of  28224
# Global Step:  93  of  28224
# Global Step:  94  of  28224
# Global Step:  95  of  28224
# Global Step:  96  of  28224
# Global Step:  97  of  28224
# Global Step:  98  of  28224
# Global Step:  99  of  28224
# Global Step:  100  of  28224
# Global Step:  101  of  28224
# Global Step:  102  of  28224
# Global Step:  103  of  28224
# Global Step:  104  of  28224
# Global Step:  105  of  28224
# Global Step:  106  of  28224
# Global Step:  107  of  28224
# Global Step:  108  of  28224
# Global Step:  109  of  28224
# Global Step:  110  of  28224
# Global Step:  111  of  28224
# Global Step:  112  of  28224
# Global Step:  113  of  28224
# Global Step:  114  of  28224
# Global Step:  115  of  28224
# Global Step:  116  of  28224
# Global Step:  117  of  28224
# Global Step:  118  of  28224
# Global Step:  119  of  28224
# Global Step:  120  of  28224
# Global Step:  121  of  28224
# Global Step:  122  of  28224
# Global Step:  123  of  28224
# Global Step:  124  of  28224
# Global Step:  125  of  28224
# Global Step:  126  of  28224
# Global Step:  127  of  28224
# Global Step:  128  of  28224
# Global Step:  129  of  28224
# Global Step:  130  of  28224
# Global Step:  131  of  28224
# Global Step:  132  of  28224
# Global Step:  133  of  28224
# Global Step:  134  of  28224
# Global Step:  135  of  28224
# Global Step:  136  of  28224
# Global Step:  137  of  28224
# Global Step:  138  of  28224
# Global Step:  139  of  28224
# Global Step:  140  of  28224
# Global Step:  141  of  28224
# Global Step:  142  of  28224
# Global Step:  143  of  28224
# Global Step:  144  of  28224
# Global Step:  145  of  28224
# Global Step:  146  of  28224
# Global Step:  147  of  28224
# Global Step:  148  of  28224
# Global Step:  149  of  28224
# Global Step:  150  of  28224
# Global Step:  151  of  28224
# Global Step:  152  of  28224
# Global Step:  153  of  28224
# Global Step:  154  of  28224
# Global Step:  155  of  28224
# Global Step:  156  of  28224
# Global Step:  157  of  28224
# Global Step:  158  of  28224
# Global Step:  159  of  28224
# Global Step:  160  of  28224
# Global Step:  161  of  28224
# Global Step:  162  of  28224
# Global Step:  163  of  28224
# Global Step:  164  of  28224
# Global Step:  165  of  28224
# Global Step:  166  of  28224
# Global Step:  167  of  28224
# Global Step:  168  of  28224
# Global Step:  169  of  28224
# Global Step:  170  of  28224
# Global Step:  171  of  28224
# Global Step:  172  of  28224
# Global Step:  173  of  28224
# Global Step:  174  of  28224
# Global Step:  175  of  28224
# Global Step:  176  of  28224
# Global Step:  177  of  28224
# Global Step:  178  of  28224
# Global Step:  179  of  28224
# Global Step:  180  of  28224
# Global Step:  181  of  28224
# Global Step:  182  of  28224
# Global Step:  183  of  28224
# Global Step:  184  of  28224
# Global Step:  185  of  28224
# Global Step:  186  of  28224
# Global Step:  187  of  28224
# Global Step:  188  of  28224
# Global Step:  189  of  28224
# Global Step:  190  of  28224
# Global Step:  191  of  28224
# Global Step:  192  of  28224
# Global Step:  193  of  28224
# Global Step:  194  of  28224
# Global Step:  195  of  28224
# Global Step:  196  of  28224
# Global Step:  197  of  28224
# Global Step:  198  of  28224
# Global Step:  199  of  28224
# Global Step:  200  of  28224
# Global Step:  201  of  28224
# Global Step:  202  of  28224
# Global Step:  203  of  28224
# Global Step:  204  of  28224
# Global Step:  205  of  28224
# Global Step:  206  of  28224
# Global Step:  207  of  28224
# Global Step:  208  of  28224
# Global Step:  209  of  28224
# Global Step:  210  of  28224
# Global Step:  211  of  28224
# Global Step:  212  of  28224
# Global Step:  213  of  28224
# Global Step:  214  of  28224
# Global Step:  215  of  28224
# Global Step:  216  of  28224
# Global Step:  217  of  28224
# Global Step:  218  of  28224
# Global Step:  219  of  28224
# Global Step:  220  of  28224
# Global Step:  221  of  28224
# Global Step:  222  of  28224
# Global Step:  223  of  28224
# Global Step:  224  of  28224
# Global Step:  225  of  28224
# Global Step:  226  of  28224
# Global Step:  227  of  28224
# Global Step:  228  of  28224
# Global Step:  229  of  28224
# Global Step:  230  of  28224
# Global Step:  231  of  28224
# Global Step:  232  of  28224
# Global Step:  233  of  28224
# Global Step:  234  of  28224
# Global Step:  235  of  28224
# Global Step:  236  of  28224
# Global Step:  237  of  28224
# Global Step:  238  of  28224
# Global Step:  239  of  28224
# Global Step:  240  of  28224
# Global Step:  241  of  28224
# Global Step:  242  of  28224
# Global Step:  243  of  28224
# Global Step:  244  of  28224
# Global Step:  245  of  28224
# Global Step:  246  of  28224
# Global Step:  247  of  28224
# Global Step:  248  of  28224
# Global Step:  249  of  28224
# Global Step:  250  of  28224
# Global Step:  251  of  28224
# Global Step:  252  of  28224
# Global Step:  253  of  28224
# Global Step:  254  of  28224
# Global Step:  255  of  28224
# Global Step:  256  of  28224
# Global Step:  257  of  28224
# Global Step:  258  of  28224
# Global Step:  259  of  28224
# Global Step:  260  of  28224
# Global Step:  261  of  28224
# Global Step:  262  of  28224
# Global Step:  263  of  28224
# Global Step:  264  of  28224
# Global Step:  265  of  28224
# Global Step:  266  of  28224
# Global Step:  267  of  28224
# Global Step:  268  of  28224
# Global Step:  269  of  28224
# Global Step:  270  of  28224
# Global Step:  271  of  28224
# Global Step:  272  of  28224
# Global Step:  273  of  28224
# Global Step:  274  of  28224
# Global Step:  275  of  28224
# Global Step:  276  of  28224
# Global Step:  277  of  28224
# Global Step:  278  of  28224
# Global Step:  279  of  28224
# Global Step:  280  of  28224
# Global Step:  281  of  28224
# Global Step:  282  of  28224
# Global Step:  283  of  28224
# Global Step:  284  of  28224
# Global Step:  285  of  28224
# Global Step:  286  of  28224
# Global Step:  287  of  28224
# Global Step:  288  of  28224
# Global Step:  289  of  28224
# Global Step:  290  of  28224
# Global Step:  291  of  28224
# Global Step:  292  of  28224
# Global Step:  293  of  28224
# Global Step:  294  of  28224
# Global Step:  295  of  28224
# Global Step:  296  of  28224
# Global Step:  297  of  28224
# Global Step:  298  of  28224
# Global Step:  299  of  28224
# Global Step:  300  of  28224
# Global Step:  301  of  28224
# Global Step:  302  of  28224
# Global Step:  303  of  28224
# Global Step:  304  of  28224
# Global Step:  305  of  28224
# Global Step:  306  of  28224
# Global Step:  307  of  28224
# Global Step:  308  of  28224
# Global Step:  309  of  28224
# Global Step:  310  of  28224
# Global Step:  311  of  28224
# Global Step:  312  of  28224
# Global Step:  313  of  28224
# Global Step:  314  of  28224
# Global Step:  315  of  28224
# Global Step:  316  of  28224
# Global Step:  426  of  28224
# Global Step:  427  of  28224
# Global Step:  428  of  28224
# Global Step:  429  of  28224
# Global Step:  430  of  28224
# Global Step:  431  of  28224
# Global Step:  432  of  28224
# Global Step:  433  of  28224
# Global Step:  434  of  28224
# Global Step:  435  of  28224
# Global Step:  436  of  28224
# Global Step:  437  of  28224
# Global Step:  438  of  28224
# Global Step:  439  of  28224
# Global Step:  440  of  28224
# Global Step:  441  of  28224
# Global Step:  442  of  28224
# Global Step:  443  of  28224
# Global Step:  444  of  28224
# Global Step:  445  of  28224
# Global Step:  446  of  28224
# Global Step:  447  of  28224
# Global Step:  448  of  28224
# Global Step:  449  of  28224
# Global Step:  450  of  28224
# Global Step:  451  of  28224
# Global Step:  452  of  28224
# Global Step:  453  of  28224
# Global Step:  454  of  28224
# Global Step:  455  of  28224
# Global Step:  456  of  28224
# Global Step:  457  of  28224
# Global Step:  458  of  28224
# Global Step:  459  of  28224
# Global Step:  460  of  28224
# Global Step:  461  of  28224
# Global Step:  462  of  28224
# Global Step:  463  of  28224
# Global Step:  464  of  28224
# Global Step:  465  of  28224
# Global Step:  466  of  28224
# Global Step:  467  of  28224
# Global Step:  468  of  28224
# Global Step:  469  of  28224
# Global Step:  470  of  28224
# Global Step:  471  of  28224
# Global Step:  472  of  28224
# Global Step:  473  of  28224
# Global Step:  474  of  28224
# Global Step:  475  of  28224
# Global Step:  476  of  28224
# Global Step:  477  of  28224
# Global Step:  478  of  28224
# Global Step:  479  of  28224
# Global Step:  480  of  28224
# Global Step:  481  of  28224
# Global Step:  482  of  28224
# Global Step:  483  of  28224
# Global Step:  484  of  28224
# Global Step:  485  of  28224
# Global Step:  486  of  28224
# Global Step:  487  of  28224
# Global Step:  488  of  28224
# Global Step:  489  of  28224
# Global Step:  490  of  28224
# Global Step:  491  of  28224
# Global Step:  492  of  28224
# Global Step:  493  of  28224
# Global Step:  494  of  28224
# Global Step:  495  of  28224
# Global Step:  496  of  28224
# Global Step:  497  of  28224
# Global Step:  498  of  28224
# Global Step:  499  of  28224
# Global Step:  500  of  28224
# Global Step:  501  of  28224
# Global Step:  502  of  28224
# Global Step:  503  of  28224
# Global Step:  504  of  28224
# Global Step:  505  of  28224
# Global Step:  506  of  28224
# Global Step:  507  of  28224
# Global Step:  508  of  28224
# Global Step:  509  of  28224
# Global Step:  510  of  28224
# Global Step:  511  of  28224
# Global Step:  512  of  28224
# Global Step:  513  of  28224
# Global Step:  514  of  28224
# Global Step:  515  of  28224
# Global Step:  516  of  28224
# Global Step:  517  of  28224
# Global Step:  518  of  28224
# Global Step:  519  of  28224
# Global Step:  520  of  28224
# Global Step:  521  of  28224
# Global Step:  522  of  28224
# Global Step:  523  of  28224
# Global Step:  524  of  28224
# Global Step:  525  of  28224
# Global Step:  526  of  28224
# Global Step:  527  of  28224
# Global Step:  528  of  28224
# Global Step:  529  of  28224
# Global Step:  530  of  28224
# Global Step:  531  of  28224
# Global Step:  532  of  28224
# Global Step:  533  of  28224
# Global Step:  534  of  28224
# Global Step:  535  of  28224
# Global Step:  536  of  28224
# Global Step:  537  of  28224
# Global Step:  538  of  28224
# Global Step:  539  of  28224
# Global Step:  540  of  28224
# Global Step:  541  of  28224
# Global Step:  542  of  28224
# Global Step:  543  of  28224
# Global Step:  544  of  28224
# Global Step:  545  of  28224
# Global Step:  546  of  28224
# Global Step:  547  of  28224
# Global Step:  548  of  28224
# Global Step:  549  of  28224
# Global Step:  550  of  28224
# Global Step:  551  of  28224
# Global Step:  552  of  28224
# Global Step:  553  of  28224
# Global Step:  554  of  28224
# Global Step:  555  of  28224
# Global Step:  556  of  28224
# Global Step:  557  of  28224
# Global Step:  558  of  28224
# Global Step:  559  of  28224
# Global Step:  560  of  28224
# Global Step:  561  of  28224
# Global Step:  562  of  28224
# Global Step:  563  of  28224
# Global Step:  564  of  28224
# Global Step:  565  of  28224
# Global Step:  566  of  28224
# Global Step:  567  of  28224
# Global Step:  568  of  28224
# Global Step:  569  of  28224
# Global Step:  570  of  28224
# Global Step:  571  of  28224
# Global Step:  572  of  28224
# Global Step:  573  of  28224
# Global Step:  574  of  28224
# Global Step:  575  of  28224
# Global Step:  576  of  28224
# Global Step:  577  of  28224
# Global Step:  578  of  28224
# Global Step:  579  of  28224
# Global Step:  580  of  28224
# Global Step:  581  of  28224
# Global Step:  582  of  28224
# Global Step:  583  of  28224
# Global Step:  584  of  28224
# Global Step:  585  of  28224
# Global Step:  586  of  28224
# Global Step:  587  of  28224
# Global Step:  588  of  28224
# Global Step:  589  of  28224
# Global Step:  590  of  28224
# Global Step:  591  of  28224
# Global Step:  592  of  28224
# Global Step:  593  of  28224
# Global Step:  594  of  28224
# Global Step:  595  of  28224
# Global Step:  596  of  28224
# Global Step:  597  of  28224
# Global Step:  598  of  28224
# Global Step:  599  of  28224
# Global Step:  600  of  28224
# Global Step:  601  of  28224
# Global Step:  602  of  28224
# Global Step:  603  of  28224
# Global Step:  604  of  28224
# Global Step:  605  of  28224
# Global Step:  606  of  28224
# Global Step:  607  of  28224
# Global Step:  608  of  28224
# Global Step:  609  of  28224
# Global Step:  610  of  28224
# Global Step:  611  of  28224
# Global Step:  612  of  28224
# Global Step:  613  of  28224
# Global Step:  614  of  28224
# Global Step:  615  of  28224
# Global Step:  616  of  28224
# Global Step:  617  of  28224
# Global Step:  618  of  28224
# Global Step:  619  of  28224
# Global Step:  620  of  28224
# Global Step:  621  of  28224
# Global Step:  622  of  28224
# Global Step:  623  of  28224
# Global Step:  624  of  28224
# Global Step:  625  of  28224
# Global Step:  626  of  28224
# Global Step:  627  of  28224
# Global Step:  628  of  28224
# Global Step:  629  of  28224
# Global Step:  630  of  28224
# Global Step:  631  of  28224
# Global Step:  632  of  28224
# Global Step:  633  of  28224
# Global Step:  634  of  28224
# Global Step:  635  of  28224
# Global Step:  636  of  28224
# Global Step:  637  of  28224
# Global Step:  638  of  28224
# Global Step:  639  of  28224
# Global Step:  640  of  28224
# Global Step:  641  of  28224
# Global Step:  642  of  28224
# Global Step:  643  of  28224
# Global Step:  754  of  28224
# Global Step:  755  of  28224
# Global Step:  756  of  28224
# Global Step:  757  of  28224
# Global Step:  758  of  28224
# Global Step:  759  of  28224
# Global Step:  760  of  28224
# Global Step:  761  of  28224
# Global Step:  762  of  28224
# Global Step:  763  of  28224
# Global Step:  764  of  28224
# Global Step:  765  of  28224
# Global Step:  766  of  28224
# Global Step:  767  of  28224
# Global Step:  768  of  28224
# Global Step:  769  of  28224
# Global Step:  770  of  28224
# Global Step:  771  of  28224
# Global Step:  772  of  28224
# Global Step:  773  of  28224
# Global Step:  774  of  28224
# Global Step:  775  of  28224
# Global Step:  776  of  28224
# Global Step:  777  of  28224
# Global Step:  778  of  28224
# Global Step:  779  of  28224
# Global Step:  780  of  28224
# Global Step:  781  of  28224
# Global Step:  782  of  28224
# Global Step:  783  of  28224
# Global Step:  784  of  28224
# Global Step:  785  of  28224
# Global Step:  786  of  28224
# Global Step:  787  of  28224
# Global Step:  788  of  28224
# Global Step:  789  of  28224
# Global Step:  790  of  28224
# Global Step:  791  of  28224
# Global Step:  792  of  28224
# Global Step:  793  of  28224
# Global Step:  794  of  28224
# Global Step:  795  of  28224
# Global Step:  796  of  28224
# Global Step:  797  of  28224
# Global Step:  798  of  28224
# Global Step:  799  of  28224
# Global Step:  800  of  28224
# Global Step:  801  of  28224
# Global Step:  802  of  28224
# Global Step:  803  of  28224
# Global Step:  804  of  28224
# Global Step:  805  of  28224
# Global Step:  806  of  28224
# Global Step:  807  of  28224
# Global Step:  808  of  28224
# Global Step:  809  of  28224
# Global Step:  810  of  28224
# Global Step:  811  of  28224
# Global Step:  812  of  28224
# Global Step:  813  of  28224
# Global Step:  814  of  28224
# Global Step:  815  of  28224
# Global Step:  816  of  28224
# Global Step:  817  of  28224
# Global Step:  818  of  28224
# Global Step:  819  of  28224
# Global Step:  820  of  28224
# Global Step:  821  of  28224
# Global Step:  822  of  28224
# Global Step:  823  of  28224
# Global Step:  824  of  28224
# Global Step:  825  of  28224
# Global Step:  826  of  28224
# Global Step:  827  of  28224
# Global Step:  828  of  28224
# Global Step:  829  of  28224
# Global Step:  830  of  28224
# Global Step:  831  of  28224
# Global Step:  832  of  28224
# Global Step:  833  of  28224
# Global Step:  834  of  28224
# Global Step:  835  of  28224
# Global Step:  836  of  28224
# Global Step:  837  of  28224
# Global Step:  838  of  28224
# Global Step:  839  of  28224
# Global Step:  840  of  28224
# Global Step:  841  of  28224
# Global Step:  842  of  28224
# Global Step:  843  of  28224
# Global Step:  844  of  28224
# Global Step:  845  of  28224
# Global Step:  846  of  28224
# Global Step:  847  of  28224
# Global Step:  848  of  28224
# Global Step:  849  of  28224
# Global Step:  850  of  28224
# Global Step:  851  of  28224
# Global Step:  852  of  28224
# Global Step:  853  of  28224
# Global Step:  854  of  28224
# Global Step:  855  of  28224
# Global Step:  856  of  28224
# Global Step:  857  of  28224
# Global Step:  858  of  28224
# Global Step:  859  of  28224
# Global Step:  860  of  28224
# Global Step:  861  of  28224
# Global Step:  862  of  28224
# Global Step:  8531  of  28224
# Global Step:  8532  of  28224
# Global Step:  8533  of  28224
# Global Step:  8534  of  28224
# Global Step:  8535  of  28224
# Global Step:  8536  of  28224
# Global Step:  8537  of  28224
# Global Step:  8538  of  28224
# Global Step:  8539  of  28224
# Global Step:  8540  of  28224
# Global Step:  8541  of  28224
# Global Step:  8542  of  28224
# Global Step:  8543  of  28224
# Global Step:  8544  of  28224
# Global Step:  8545  of  28224
# Global Step:  8546  of  28224
# Global Step:  8547  of  28224
# Global Step:  8548  of  28224
# Global Step:  8549  of  28224
# Global Step:  8550  of  28224
# Global Step:  8551  of  28224
# Global Step:  8552  of  28224
# Global Step:  8553  of  28224
# Global Step:  8554  of  28224
# Global Step:  8555  of  28224
# Global Step:  8556  of  28224
# Global Step:  8557  of  28224
# Global Step:  8558  of  28224
# Global Step:  8559  of  28224
# Global Step:  8560  of  28224
# Global Step:  8561  of  28224
# Global Step:  8562  of  28224
# Global Step:  8563  of  28224
# Global Step:  8564  of  28224
# Global Step:  8565  of  28224
# Global Step:  8566  of  28224
# Global Step:  8567  of  28224
# Global Step:  8568  of  28224
# Global Step:  8569  of  28224
# Global Step:  8570  of  28224
# Global Step:  8571  of  28224
# Global Step:  8572  of  28224
# Global Step:  8573  of  28224
# Global Step:  8574  of  28224
# Global Step:  8575  of  28224
# Global Step:  8576  of  28224
# Global Step:  8577  of  28224
# Global Step:  8578  of  28224
# Global Step:  8579  of  28224
# Global Step:  8580  of  28224
# Global Step:  8581  of  28224
# Global Step:  8582  of  28224
# Global Step:  8583  of  28224
# Global Step:  8584  of  28224
# Global Step:  8585  of  28224
# Global Step:  8586  of  28224
# Global Step:  8587  of  28224
# Global Step:  8588  of  28224
# Global Step:  8589  of  28224
# Global Step:  8590  of  28224
# Global Step:  8591  of  28224
# Global Step:  8592  of  28224
# Global Step:  8593  of  28224
# Global Step:  8594  of  28224
# Global Step:  8595  of  28224
# Global Step:  8596  of  28224
# Global Step:  8597  of  28224
# Global Step:  8598  of  28224
# Global Step:  8599  of  28224
# Global Step:  8600  of  28224
# Global Step:  8601  of  28224
# Global Step:  8602  of  28224
# Global Step:  8603  of  28224
# Global Step:  8604  of  28224
# Global Step:  8605  of  28224
# Global Step:  8606  of  28224
# Global Step:  8607  of  28224
# Global Step:  8608  of  28224
# Global Step:  8609  of  28224
# Global Step:  8610  of  28224
# Global Step:  8611  of  28224
# Global Step:  8612  of  28224
# Global Step:  8613  of  28224
# Global Step:  8614  of  28224
# Global Step:  8615  of  28224
# Global Step:  8616  of  28224
# Global Step:  8617  of  28224
# Global Step:  8618  of  28224
# Global Step:  8619  of  28224
# Global Step:  8620  of  28224
# Global Step:  8621  of  28224
# Global Step:  8622  of  28224
# Global Step:  8623  of  28224
# Global Step:  8624  of  28224
# Global Step:  8625  of  28224
# Global Step:  8626  of  28224
# Global Step:  8627  of  28224
# Global Step:  8628  of  28224
# Global Step:  8629  of  28224
# Global Step:  8630  of  28224
# Global Step:  8631  of  28224
# Global Step:  8632  of  28224
# Global Step:  8633  of  28224
# Global Step:  8634  of  28224
# Global Step:  8635  of  28224
# Global Step:  8636  of  28224
# Global Step:  8637  of  28224
# Global Step:  8638  of  28224
# Global Step:  8639  of  28224
# Global Step:  8640  of  28224
# Global Step:  8641  of  28224
# Global Step:  8642  of  28224
# Global Step:  8643  of  28224
# Global Step:  8644  of  28224
# Global Step:  8645  of  28224
# Global Step:  8646  of  28224
# Global Step:  8647  of  28224
# Global Step:  8648  of  28224
# Global Step:  8649  of  28224
# Global Step:  8650  of  28224
# Global Step:  8651  of  28224
# Global Step:  8652  of  28224
# Global Step:  8653  of  28224
# Global Step:  8654  of  28224
# Global Step:  8655  of  28224
# Global Step:  8656  of  28224
# Global Step:  8657  of  28224
# Global Step:  8658  of  28224
# Global Step:  8659  of  28224
# Global Step:  8660  of  28224
# Global Step:  8661  of  28224
# Global Step:  8662  of  28224
# Global Step:  8663  of  28224
# Global Step:  8664  of  28224
# Global Step:  8665  of  28224
# Global Step:  8666  of  28224
# Global Step:  8667  of  28224
# Global Step:  8668  of  28224
# Global Step:  8669  of  28224
# Global Step:  8670  of  28224
# Global Step:  8671  of  28224
# Global Step:  8672  of  28224
# Global Step:  8673  of  28224
# Global Step:  8674  of  28224
# Global Step:  8675  of  28224
# Global Step:  8676  of  28224
# Global Step:  8677  of  28224
# Global Step:  8678  of  28224
# Global Step:  8679  of  28224
# Global Step:  8680  of  28224
# Global Step:  8681  of  28224
# Global Step:  8682  of  28224
# Global Step:  8683  of  28224
# Global Step:  8684  of  28224
# Global Step:  8685  of  28224
# Global Step:  8686  of  28224
# Global Step:  8687  of  28224
# Global Step:  8688  of  28224
# Global Step:  8689  of  28224
# Global Step:  8690  of  28224
# Global Step:  8691  of  28224
# Global Step:  8692  of  28224
# Global Step:  8693  of  28224
# Global Step:  8694  of  28224
# Global Step:  8695  of  28224
# Global Step:  8696  of  28224
# Global Step:  8697  of  28224
# Global Step:  8698  of  28224
# Global Step:  8699  of  28224
# Global Step:  8700  of  28224
# Global Step:  8701  of  28224
# Global Step:  8702  of  28224
# Global Step:  8703  of  28224
# Global Step:  8704  of  28224
# Global Step:  8705  of  28224
# Global Step:  8706  of  28224
# Global Step:  8707  of  28224
# Global Step:  8708  of  28224
# Global Step:  8709  of  28224
# Global Step:  8710  of  28224
# Global Step:  8711  of  28224
# Global Step:  8712  of  28224
# Global Step:  8713  of  28224
# Global Step:  8714  of  28224
# Global Step:  8715  of  28224
# Global Step:  8716  of  28224
# Global Step:  8717  of  28224
# Global Step:  8718  of  28224
# Global Step:  8719  of  28224
# Global Step:  8720  of  28224
# Global Step:  8721  of  28224
# Global Step:  8722  of  28224
# Global Step:  8723  of  28224
# Global Step:  8724  of  28224
# Global Step:  8725  of  28224
# Global Step:  8726  of  28224
# Global Step:  8727  of  28224
# Global Step:  8728  of  28224
# Global Step:  8729  of  28224
# Global Step:  8730  of  28224
# Global Step:  8731  of  28224
# Global Step:  8732  of  28224
# Global Step:  8733  of  28224
# Global Step:  8734  of  28224
# Global Step:  8837  of  28224
# Global Step:  8838  of  28224
# Global Step:  8839  of  28224
# Global Step:  8840  of  28224
# Global Step:  8841  of  28224
# Global Step:  8842  of  28224
# Global Step:  8844  of  28224
# Global Step:  8845  of  28224
# Global Step:  8846  of  28224
# Global Step:  8847  of  28224
# Global Step:  8848  of  28224
# Global Step:  8849  of  28224
# Global Step:  8850  of  28224
# Global Step:  8851  of  28224
# Global Step:  8852  of  28224
# Global Step:  8853  of  28224
# Global Step:  8854  of  28224
# Global Step:  8855  of  28224
# Global Step:  8856  of  28224
# Global Step:  8857  of  28224
# Global Step:  8858  of  28224
# Global Step:  8859  of  28224
# Global Step:  8860  of  28224
# Global Step:  8861  of  28224
# Global Step:  8862  of  28224
# Global Step:  8863  of  28224
# Global Step:  8864  of  28224
# Global Step:  8865  of  28224
# Global Step:  8866  of  28224
# Global Step:  8867  of  28224
# Global Step:  8868  of  28224
# Global Step:  8869  of  28224
# Global Step:  8870  of  28224
# Global Step:  8871  of  28224
# Global Step:  8872  of  28224
# Global Step:  8873  of  28224
# Global Step:  8874  of  28224
# Global Step:  8875  of  28224
# Global Step:  8876  of  28224
# Global Step:  8877  of  28224
# Global Step:  8878  of  28224
# Global Step:  8879  of  28224
# Global Step:  8880  of  28224
# Global Step:  8881  of  28224
# Global Step:  8882  of  28224
# Global Step:  8883  of  28224
# Global Step:  8884  of  28224
# Global Step:  8885  of  28224
# Global Step:  8886  of  28224
# Global Step:  8887  of  28224
# Global Step:  8888  of  28224
# Global Step:  8889  of  28224
# Global Step:  8890  of  28224
# Global Step:  8891  of  28224
# Global Step:  8892  of  28224
# Global Step:  8893  of  28224
# Global Step:  8894  of  28224
# Global Step:  8895  of  28224
# Global Step:  8896  of  28224
# Global Step:  8897  of  28224
# Global Step:  8898  of  28224
# Global Step:  8899  of  28224
# Global Step:  8900  of  28224
# Global Step:  8901  of  28224
# Global Step:  8902  of  28224
# Global Step:  8903  of  28224
# Global Step:  8904  of  28224
# Global Step:  8905  of  28224
# Global Step:  8906  of  28224
# Global Step:  8907  of  28224
# Global Step:  8908  of  28224
# Global Step:  8909  of  28224
# Global Step:  8910  of  28224
# Global Step:  8911  of  28224
# Global Step:  8912  of  28224
# Global Step:  8913  of  28224
# Global Step:  8914  of  28224
# Global Step:  8915  of  28224
# Global Step:  8916  of  28224
# Global Step:  8917  of  28224
# Global Step:  8918  of  28224
# Global Step:  8919  of  28224
# Global Step:  8920  of  28224
# Global Step:  8921  of  28224
# Global Step:  8922  of  28224
# Global Step:  8923  of  28224
# Global Step:  8924  of  28224
# Global Step:  8925  of  28224
# Global Step:  8926  of  28224
# Global Step:  8927  of  28224
# Global Step:  8928  of  28224
# Global Step:  8929  of  28224
# Global Step:  8930  of  28224
# Global Step:  8931  of  28224
# Global Step:  8932  of  28224
# Global Step:  8933  of  28224
# Global Step:  8934  of  28224
# Global Step:  8935  of  28224
# Global Step:  8936  of  28224
# Global Step:  8937  of  28224
# Global Step:  8938  of  28224
# Global Step:  8939  of  28224
# Global Step:  8940  of  28224
# Global Step:  8941  of  28224
# Global Step:  8942  of  28224
# Global Step:  8943  of  28224
# Global Step:  8944  of  28224
# Global Step:  8945  of  28224
# Global Step:  8946  of  28224
# Global Step:  8947  of  28224
# Global Step:  8948  of  28224
# Global Step:  8949  of  28224
# Global Step:  8950  of  28224
# Global Step:  8951  of  28224
# Global Step:  8952  of  28224
# Global Step:  8953  of  28224
# Global Step:  8954  of  28224
# Global Step:  8955  of  28224
# Global Step:  8956  of  28224
# Global Step:  8957  of  28224
# Global Step:  8958  of  28224
# Global Step:  8959  of  28224
# Global Step:  8960  of  28224
# Global Step:  8961  of  28224
# Global Step:  8962  of  28224
# Global Step:  8963  of  28224
# Global Step:  8964  of  28224
# Global Step:  8965  of  28224
# Global Step:  8966  of  28224
# Global Step:  8967  of  28224
# Global Step:  8968  of  28224
# Global Step:  8969  of  28224
# Global Step:  8970  of  28224
# Global Step:  8971  of  28224
# Global Step:  8972  of  28224
# Global Step:  8973  of  28224
# Global Step:  8974  of  28224
# Global Step:  8975  of  28224
# Global Step:  8976  of  28224
# Global Step:  8977  of  28224
# Global Step:  8978  of  28224
# Global Step:  8979  of  28224
# Global Step:  8980  of  28224
# Global Step:  8981  of  28224
# Global Step:  8982  of  28224
# Global Step:  8983  of  28224
# Global Step:  8984  of  28224
# Global Step:  8985  of  28224
# Global Step:  8986  of  28224
# Global Step:  8987  of  28224
# Global Step:  8988  of  28224
# Global Step:  8989  of  28224
# Global Step:  8990  of  28224
# Global Step:  8991  of  28224
# Global Step:  8992  of  28224
# Global Step:  8993  of  28224
# Global Step:  8994  of  28224
# Global Step:  8995  of  28224
# Global Step:  8996  of  28224
# Global Step:  8997  of  28224
# Global Step:  8998  of  28224
# Global Step:  8999  of  28224
# Global Step:  9000  of  28224
# Global Step:  9001  of  28224
# Global Step:  9002  of  28224
# Global Step:  9003  of  28224
# Global Step:  9004  of  28224
# Global Step:  9005  of  28224
# Global Step:  9006  of  28224
# Global Step:  9007  of  28224
# Global Step:  9008  of  28224
# Global Step:  9009  of  28224
# Global Step:  9010  of  28224
# Global Step:  9011  of  28224
# Global Step:  9012  of  28224
# Global Step:  9013  of  28224

# %%
# store important parameters 
important_hyperparams = {
    'training_data':TRAIN_DATA,
    'batch_size':BATCH_SIZE,
    'student':STUDENT,
    'learning_rate':LEARNING_RATE,
    'learning_rate_scheduler':SCHEDULER_CLASS,
    'temperature': TEMPERATURE,
    'temp_scheduler':TEMPERATURE_SCHEDULER,
    'loss_weights: kd, int_match': [KD_LOSS_WEIGHT, INT_LOSS_WEIGHT],
    'kd_weight_scheduler': KD_WEIGHT_SCHEDULER,
    'int_matches': INTERMEDIATE_MATCHES,
    'optimizer':OPTIMIZER,
    'student_config': student_config,
    'training_time':training_time
}

# %%
# display
important_hyperparams

# %%
# save the important hyperparams 
path = LOG_DIR + '/PARAMS.json'
save_json(important_hyperparams, path)

# %%
# save the model
path = LOG_DIR + '/trained_model_{}'.format(time.time())
write_torch(student_model.state_dict(), path)
